# %% [markdown]
# # Get and Hash all VASP data in the MDF

# %%
import globus_sdk
from mdf_forge.forge import Forge

import dfttopif

from ase.io import vasp
from ase import Atoms

import codecs

from joblib import Parallel, delayed

from pypif import pif
import gzip
import os
import json
import io
import requests
from tempfile import TemporaryDirectory

# %%
DEFAULT_DIR = "pifs"

# %% [markdown]
# ## Get All VASP Records
# This section gathers all VASP records from the MDF

# %%
forge = Forge()

# %% [markdown]
# Find all applicable data

# %%
query_string = "mdf.tags:outcar AND mdf.resource_type:record"
#query_string += " AND mdf.source_name:trinkle_elastic_fe_bcc"
query_string += " AND (mdf.source_name:ti_o_meam_model OR mdf.source_name:khazana_vasp)"

all_results = forge.aggregate(query_string, scroll_size=1000)

result_records = {}
for result in all_results:
    source = result["mdf"]["source_name"]
    if source not in result_records.keys():
        result_records[source] = []
    result_records[source].append(result)

print('Found %d sources'%len(result_records.keys()))
print('Found %d records'%len(all_results))
#result_records[0]
result_records
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 83.20it/s]
# Found 2 sources
# Found 40 records
# {'khazana_vasp': [{'mdf': {'collection': 'Khazana',
#     'composition': 'Al128',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:27:06.214936Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#7',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_bcc_large'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca8af2c00438032d6a9b',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 7,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al128'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:29:43.954072Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#11',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_bulk_1250K'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb27f2c00438032d6a9f',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 11,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al249',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:00.447361Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#12',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_cluster_10A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb38f2c00438032d6aa0',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 12,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al249'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al55',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:28.443528Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#14',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_cluster_5A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb54f2c00438032d6aa2',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 14,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al55'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al60',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:56.875257Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#19',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_gb_210'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb70f2c00438032d6aa7',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 19,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al60'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al42',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:31:04.910712Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#20',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_gb_310'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb78f2c00438032d6aa8',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 20,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al42'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al128',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:31:58.571717Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#25',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_110'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cbaef2c00438032d6aad',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 25,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al128'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:25:18.989375Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#1',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_3.75A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca1ef2c00438032d6a95',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 1,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:25:46.683659Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#2',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_3.96A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca3af2c00438032d6a96',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 2,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:26:32.500604Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#4',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_4.15A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca68f2c00438032d6a98',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 4,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:26:57.523495Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#5',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_4.1A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca81f2c00438032d6a99',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 5,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al254',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:27:39.880273Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#8',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_bulk+2vac'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984caabf2c00438032d6a9c',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 8,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al254'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al378',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:41.389345Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#16',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_dislocation'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb61f2c00438032d6aa4',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 16,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al378'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al837',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:41.783507Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#17',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_fcc_large'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb61f2c00438032d6aa5',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 17,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al837'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al24',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:50.796417Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#18',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_gb_111'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb6af2c00438032d6aa6',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 18,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al24'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al96',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:31:08.445242Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#21',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_gb_320'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb7cf2c00438032d6aa9',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 21,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al96'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al17',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:32:34.470511Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#28',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_111_adatom'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cbd2f2c00438032d6ab0',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 28,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al17'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al108',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:32:42.216853Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#30',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_333'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cbdaf2c00438032d6ab2',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 30,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al108'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:26:09.243045Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#3',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_4.0A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca51f2c00438032d6a97',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 3,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al32',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:27:06.120436Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#6',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_4.35A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984ca8af2c00438032d6a9a',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 6,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al32'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al860',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:28:13.345402Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#9',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_bulk+6vac'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cacdf2c00438032d6a9d',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 9,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al860'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al31',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:29:31.653231Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#10',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_bulk+vac'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb1bf2c00438032d6a9e',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 10,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al31'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al429',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:20.729560Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#13',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_cluster_12A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb4cf2c00438032d6aa1',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 13,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al429'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al135',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:30:36.630695Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#15',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_cluster_8A'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb5cf2c00438032d6aa3',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 15,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al135'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al70',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:31:16.816840Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#22',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_gb_510'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb84f2c00438032d6aaa',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 22,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al70'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al144',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:31:18.732791Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#23',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_100'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cb86f2c00438032d6aab',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 23,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al144'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al76',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:31:51.015606Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#24',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_100_adatom'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cba7f2c00438032d6aac',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 24,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al76'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al129',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:32:06.278095Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#26',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_110_adatom'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cbb6f2c00438032d6aae',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 26,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al129'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al16',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:32:16.573750Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#27',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_111'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cbc0f2c00438032d6aaf',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 27,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al16'}},
#   {'mdf': {'collection': 'Khazana',
#     'composition': 'Al108',
#     'elements': ['Al'],
#     'ingest_date': '2017-08-04T19:32:38.730949Z',
#     'links': {'landing_page': 'http://khazana.uconn.edu/module_search/search.php?m=2#29',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/khazana/OUTCARS/OUTCAR_surface_200'},
#      'parent_id': '5984ca11f2c00438032d6a94'},
#     'mdf_id': '5984cbd6f2c00438032d6ab1',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 29,
#     'source_name': 'khazana_vasp',
#     'tags': ['outcar'],
#     'title': 'Khazana VASP - Al108'}}],
#  'ti_o_meam_model': [{'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O4Ti2',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:45.848884Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#1',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/RutileTiO2_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d015f2c004388b77e808',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 1,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O4Ti2'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'OTi24',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:48.707476Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#8',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/bct_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d018f2c004388b77e80f',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 8,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - OTi24'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O10Ti10',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:48.423915Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#7',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/TiO-alpha_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d018f2c004388b77e80e',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 7,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O10Ti10'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'OTi96',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:51.624548Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#9',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/hcpDiffusion_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d01bf2c004388b77e810',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 9,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - OTi96'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O4Ti64',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:54.345331Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#10',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/hcpElastic_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d01ef2c004388b77e811',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 10,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O4Ti64'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O18Ti12',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:46.455783Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#2',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/Ti2O3_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d016f2c004388b77e809',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 2,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O18Ti12'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O8Ti12',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:47.735176Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#3',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/Ti3O2_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d017f2c004388b77e80a',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 3,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O8Ti12'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'OTi',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:48.238916Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#4',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/TiO-CsCl_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d018f2c004388b77e80b',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 4,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - OTi'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O4Ti4',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:48.311122Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#5',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/TiO-RockSalt_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d018f2c004388b77e80c',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 5,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O4Ti4'}},
#   {'mdf': {'collection': 'Ti-O MEAM Model',
#     'composition': 'O4Ti4',
#     'elements': ['O', 'Ti'],
#     'ingest_date': '2017-08-04T19:50:48.370665Z',
#     'links': {'landing_page': 'https://materialsdata.nist.gov/dspace/xmlui/handle/11115/244#6',
#      'outcar': {'globus_endpoint': '82f1b5c6-6e9b-11e5-ba47-22000b92c6ec',
#       'http_host': 'https://data.materialsdatafacility.org',
#       'path': '/collections/Ti-O-eam/TiO-ZincBlende_VASP/OUTCAR'},
#      'parent_id': '5984d015f2c004388b77e807'},
#     'mdf_id': '5984d018f2c004388b77e80d',
#     'metadata_version': '0.3.2',
#     'resource_type': 'record',
#     'scroll_id': 6,
#     'source_name': 'ti_o_meam_model',
#     'tags': ['outcar'],
#     'title': 'Ti-O MEAM Model - O4Ti4'}}]}

# %% [markdown]
# A utility operation for getting files from the MDF.

# %%
def file_request(url, **kwargs):
    """Opens a file at the MDF
    
    :param url: str, path to file
    :param kwargs: these get passed to `requests.get`"""
    
    headers = {}
    forge.mdf_authorizer.set_authorization_header(headers)
    return requests.get(url, headers=headers, **kwargs)
# Test getting a single file
#assert file_request(
#    result_records[0]['mdf']['links']['outcar']['http_host'] +
#    result_records[0]['mdf']['links']['outcar']['path']
#).status_code == 200

# %% [markdown]
# For each entry, read the structure from the data stored in the MDF. The MDF has a complete record of the data for each OQMD calculation that, while useful, does not make sense to include in a search index.

# %%
def get_file(url, directory, name):
    """Download files from url to a directory
    
    :param directory: str, path to download directory
    :param url: str, url to download
    :param name: str, new name of file
    
    :return: int, 200 on success, url status code otherwise"""
    
    req = file_request(url, stream=True)
    
    if req.status_code != 200:
        return req.status_code
    
    # If the URL ends with ".gz" uncompress it
    with open(os.path.join(directory, name), 'wb') as fp:
        if url.endswith('.gz'):
            with gzip.open(req.raw) as go:
                for data in go:
                    fp.write(data)
        else:
            for data in req.iter_content():
                fp.write(data)
    return 200

#with TemporaryDirectory() as d:
#    url = result_records[0]['mdf']['links']['outcar']['http_host'] + \
#        result_records[0]['mdf']['links']['outcar']['path']
#    get_file(url, d, 'OUTCAR')
#    assert os.path.isfile(os.path.join(d,'OUTCAR'))
#    assert isinstance(vasp.read_vasp_out(os.path.join(d,'OUTCAR')), Atoms)

# %%
def convert_to_pif(entry, directory='pifs', overwrite=False):
    """Get the composition, structure, band gap, and stability of an entry given its search result
    
    :param entry: dict, metadata for an entry as returned by Globus search
    :param overwrite: boolean, whether to overwrite existing file, if present
    :return: 
        - bool, whether successful
        - if successful, - str, path to file
        - if not successful, - str, error message"""
    
    if not os.path.isdir(directory):
        if not os.path.exists(directory):
            os.makedirs(directory, exist_ok=True)
        else:
            raise IOError("Path " + directory + " exists and is not a directory.")
    filename = os.path.join(directory, '%s.json'%entry['mdf']['mdf_id'])
    if os.path.isfile(filename) and not overwrite:
        return True, filename
    
    # Get the path to the OUTCAR
    url = entry['mdf']['links']['outcar']['http_host'] + entry['mdf']['links']['outcar']['path']
        
    # If doesn't end with OUTCAR, skip this calculation (assuming that if OUTCAR renamed, INCAR gone)
    #   You might want to adjust this later
    if not 'OUTCAR' in os.path.basename(url):
        return False, 'Not an OUTCAR'
    
    base_url = '/'.join(url.split('/')[:-1]) + '/'
    
    # Download the files
    with TemporaryDirectory() as d:
        try:
            # Download OUTCAR
            get_file(url, d, 'OUTCAR')
                
            # Download optional files
            for f in ['INCAR','POSCAR','KPOINTS','DOSCAR']:
                result = get_file(base_url+f,d,f)
                
            # Run the DFT to pif
            try:
                mypif = dfttopif.drivers.directory_to_pif(d, quality_report=False)
            except:
                return False, 'dftotopif failed'
            
            # Convert (or [debug], return the pif)
            pif.dump(mypif, open(filename, 'w'))
            return True, filename
        except:
            raise
#result, path = convert_to_pif(result_records[0], 'pifs')
#assert result
#assert os.path.isfile(path)

# %% [markdown]
# Process all of the records in parallel

# %%
with Parallel(n_jobs=20, verbose=11) as p:
    f = delayed(convert_to_pif)
    pif_results = []
    for source, results in result_records.items():
        output_dir = os.path.join(DEFAULT_DIR, source)
        pif_results.extend(p([f(e, directory=output_dir, overwrite=True) for e in results]))
print('%d of %d successful'%(sum([x[0] for x in pif_results]), len(pif_results)))
# Out:
# [Parallel(n_jobs=20)]: Done   1 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=20)]: Done   2 out of  10 | elapsed:   27.7s remaining:  1.8min
# [Parallel(n_jobs=20)]: Done   3 out of  10 | elapsed:   37.3s remaining:  1.5min
# [Parallel(n_jobs=20)]: Done   4 out of  10 | elapsed:   49.9s remaining:  1.2min
# [Parallel(n_jobs=20)]: Done   5 out of  10 | elapsed:  1.3min remaining:  1.3min
# [Parallel(n_jobs=20)]: Done   6 out of  10 | elapsed:  3.5min remaining:  2.3min
# [Parallel(n_jobs=20)]: Done   7 out of  10 | elapsed:  3.5min remaining:  1.5min
# [Parallel(n_jobs=20)]: Done   8 out of  10 | elapsed:  5.1min remaining:  1.3min
# [Parallel(n_jobs=20)]: Done  10 out of  10 | elapsed:  8.2min remaining:    0.0s
# [Parallel(n_jobs=20)]: Done  10 out of  10 | elapsed:  8.2min finished
# [Parallel(n_jobs=20)]: Done   1 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=20)]: Done   3 out of  30 | elapsed: 14.5min remaining: 130.9min
# [Parallel(n_jobs=20)]: Done   6 out of  30 | elapsed: 42.2min remaining: 168.9min
# [Parallel(n_jobs=20)]: Done   9 out of  30 | elapsed: 52.9min remaining: 123.5min
# [Parallel(n_jobs=20)]: Done  12 out of  30 | elapsed: 95.8min remaining: 143.7min
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-14:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-55b02845d10b> in <module>()
#       4     for source, results in result_records.items():
#       5         output_dir = os.path.join(DEFAULT_DIR, source)
# ----> 6         pif_results.extend(p([f(e, directory=output_dir, overwrite=True) for e in results]))
#       7 print('%d of %d successful'%(sum([x[0] for x in pif_results]), len(pif_results)))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
